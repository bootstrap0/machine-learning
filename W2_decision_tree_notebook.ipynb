# %% [markdown]
# <a href="https://colab.research.google.com/github/bootstrap0/machine-learning/blob/main/W2_decision_tree_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><font size=8>Hands-on - Decision Trees</font></center>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score

df = pd.read_csv('data.csv')
data = df.copy()
# defining the explanatory (independent) and response (dependent) variables
x = data.drop(["Species"], axis=1)
y = data["Species"]

# splitting the data in an 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# Assuming X_train, X_test, y_train, y_test are predefined
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred, average='macro')
precision = precision_score(y_test, y_pred, average='macro')

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')
data = df.copy()
# defining the explanatory (independent) and response (dependent) variables
x = data.drop(["Species"], axis=1)
y = data["Species"]

# splitting the data in an 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)

# Assuming X_train, X_test, y_train, y_test are predefined
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Compute the confusion matrix comparing the true target values with the predicted values
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')

data = df.copy()
# defining the explanatory (independent) and response (dependent) variables
x = data.drop(["Species"], axis=1)
y = data["Species"]

# splitting the data in an 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# Assuming X_train, X_test, y_train, y_test are predefined
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# plotting the decision tree
plot_tree(
    model,
    filled=True,                    # fill the nodes with colors based on class
    fontsize=9,                     # font size for the node text
    node_ids=False,                 # do not show the ID of each node
    class_names=None,               # whether or not to display class names
)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, recall_score

df = pd.read_csv('data.csv')

data = df.copy()
# defining the explanatory (independent) and response (dependent) variables
x = data.drop(["Species"], axis=1)
y = data["Species"]

# splitting the data in an 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# Assuming X_train, X_test, y_train, y_test are predefined
model = DecisionTreeClassifier(max_depth=3)
model.fit(X_train, y_train)
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

accuracy_train = accuracy_score(y_train, y_pred_train)
recall_train = recall_score(y_train, y_pred_train, average='macro')
accuracy_test = accuracy_score(y_test, y_pred_test)
recall_test = recall_score(y_test, y_pred_test, average='macro')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import recall_score

# Load the dataset
df = pd.read_csv('data.csv')

data = df.copy()
# defining the explanatory (independent) and response (dependent) variables
x = data.drop(["Species"], axis=1)
y = data["Species"]

# splitting the data in an 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

param_grid = {
    'max_depth': [1, 2, 3],
    'min_samples_leaf': [2, 3, 5]
}

model = DecisionTreeClassifier(max_depth=3)

# Use GridSearchCV
grid_search = GridSearchCV(model, param_grid, scoring='recall_weighted', cv=5)
# Fit GridSearchCV on training data
grid_search.fit(X_train, y_train)

# Store the best parameters
best_params = grid_search.best_params_
# Store the best recall score
best_recall = grid_search.best_score_

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import recall_score

# Load the dataset
df = pd.read_csv('data.csv')

data = df.copy()
X = data[['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin']]
y = data["origin"]
X.drop('origin', axis=1, inplace=True)

X_dummies = pd.get_dummies(X, columns=['model year'], dtype=float)

# splitting the data in an 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.20, random_state=42)

dtree = DecisionTreeClassifier(random_state=1)
dtree.fit(X_train, y_train)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the dataset
df = pd.read_csv('data.csv')

data = df.copy()
X = data[['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin']]
y = data["origin"]
X.drop('origin', axis=1, inplace=True)

X_dummies = pd.get_dummies(X, columns=['model year'], dtype=float)

# splitting the data in an 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.20, random_state=42)

dtree = DecisionTreeClassifier(random_state=1)
dtree.fit(X_train, y_train)
y_pred = dtree.predict(X_train)
train_acc = accuracy_score(y_train, y_pred)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the dataset
df = pd.read_csv('data.csv')

data = df.copy()
X = data[['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin']]
y = data["origin"]
X.drop('origin', axis=1, inplace=True)

X_dummies = pd.get_dummies(X, columns=['model year'], dtype=float)

# splitting the data in an 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.30, random_state=1)

dtree = DecisionTreeClassifier(random_state=1, max_depth=5)
dtree.fit(X_train, y_train)
y_train_pred = dtree.predict(X_train)
y_test_pred = dtree.predict(X_test)
train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the dataset
df = pd.read_csv('data.csv')

data = df.copy()
X = data[['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin']]
y = data["origin"]
X.drop('origin', axis=1, inplace=True)

X_dummies = pd.get_dummies(X, columns=['model year'], dtype=float)

# splitting the data in an 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.30, random_state=1)

dtree = DecisionTreeClassifier(random_state=1, max_depth=2)
dtree.fit(X_train, y_train)
y_train_pred = dtree.predict(X_train)
y_test_pred = dtree.predict(X_test)
train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the dataset
df = pd.read_csv('data.csv')

data = df.copy()
X = data[['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin']]
y = data["origin"]
X.drop('origin', axis=1, inplace=True)

X_dummies = pd.get_dummies(X, columns=['model year'], dtype=float)

# splitting the data in an 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.30, random_state=1)

dtree = DecisionTreeClassifier(random_state=1, max_depth=9)
dtree.fit(X_train, y_train)
y_train_pred = dtree.predict(X_train)
y_test_pred = dtree.predict(X_test)
train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)
if (train_acc > test_acc):
    overfitting = 1
else:
    overfitting = 0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('data.csv')

data = df.copy()
X = data[['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin']]
y = data['origin']
X.drop('origin', axis=1, inplace=True)

X_dummies = pd.get_dummies(X, columns=['model year'], dtype=float)

# splitting the data in an 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.30, random_state=1)

dtree = DecisionTreeClassifier(random_state=1, max_depth=3)
dtree.fit(X_train, y_train)
y_train_pred = dtree.predict(X_train)
y_test_pred = dtree.predict(X_test)
train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)

root_node_name = 'displacement'

# plotting the decision tree
tree_plot = plot_tree(
    dtree,
    filled=True,                    # fill the nodes with colors based on class
    fontsize=9,                     # font size for the node text
    node_ids=False,                 # do not show the ID of each node
    class_names=None,               # whether or not to display class names
)
plt.show()

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('data.csv')

data = df.copy()
X = data[['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin']]
y = X['origin']
X.drop('origin', axis=1, inplace=True)

X_dummies = pd.get_dummies(X, columns=['model year'], dtype=float)

# splitting the data in an 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.30, random_state=1)

# define the parameters of the tree to iterate over
max_depth_values = np.arange(2, 11, 3)
max_leaf_nodes_values = np.arange(10, 21, 10)

# initialize variables to store the best model and its performance
best_max_depth = None
best_max_leaf_node = None
diff_f1_score = float('inf')

# iterate over all combinations of the specified parameter values
for max_depth in max_depth_values:
    for max_leaf_nodes in max_leaf_nodes_values:
        # initialize the tree with the current set of parameters
        estimator = DecisionTreeClassifier(
            max_depth=max_depth,
            max_leaf_nodes=max_leaf_nodes,
            random_state=1
        )

        # fit the model to the training data
        estimator.fit(X_train, y_train)

        # make predictions on the training and test sets
        y_train_pred = estimator.predict(X_train)
        y_test_pred = estimator.predict(X_test)

        # calculate F1 scores for training and test sets
        train_f1 = f1_score(y_train, y_train_pred, average='macro')
        test_f1 = f1_score(y_test, y_test_pred, average='macro')

        # update the best estimator and best score if the current one has a smaller score difference
        if train_f1 > test_f1:
            f1_diff = abs(train_f1 - test_f1)
            if(f1_diff < diff_f1_score):
                diff_f1_score = f1_diff
                best_max_depth = max_depth
                best_max_leaf_node = max_leaf_nodes
                dtree = estimator
